# %%
# Import required libraries
import pandas as pd
import numpy as np

# Read Excel file with all sheets
excel_file = "02. Datapaket till Lund.xlsx"

print("Reading Excel file...")
print(f"File: {excel_file}")

# Get all sheet names first
xlsx_file = pd.ExcelFile(excel_file)
sheet_names = xlsx_file.sheet_names

print(f"Found {len(sheet_names)} sheets: {sheet_names}")

# Read all sheets into a dictionary of DataFrames
dataframes = {}
for sheet_name in sheet_names:
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    dataframes[sheet_name]= df
    print(f"\n Sheet '{sheet_name}' loaded:")
    print(f"   Shape: {df.shape} (rows x columns)")
    print(f"   Columns: {list(df.columns)}")

print(f"\nSuccessfully loaded {len(dataframes)} DataFrames!")
print(f"Access them using: dataframes['sheet_name']")
# Out:
# Reading Excel file...
# File: 02. Datapaket till Lund.xlsx
# Found 6 sheets: ['Masterdata', 'Inbound_95%', 'Inbound_Avg', 'Inventory', 'Picking_95%', 'Picking_Avg']
#
#  Sheet 'Masterdata' loaded:
#    Shape: (86174, 5) (rows x columns)
#    Columns: ['SKU', 'Weight [kg]', 'Length [cm]', 'Width [cm]', 'Height [cm]']
#
#  Sheet 'Masterdata' loaded:
#    Shape: (86174, 5) (rows x columns)
#    Columns: ['SKU', 'Weight [kg]', 'Length [cm]', 'Width [cm]', 'Height [cm]']
#
#  Sheet 'Inbound_95%' loaded:
#    Shape: (4083, 4) (rows x columns)
#    Columns: ['SKU', 'Inbound_order', 'Quantity_Received', 'Date']
#
#  Sheet 'Inbound_95%' loaded:
#    Shape: (4083, 4) (rows x columns)
#    Columns: ['SKU', 'Inbound_order', 'Quantity_Received', 'Date']
#
#  Sheet 'Inbound_Avg' loaded:
#    Shape: (3365, 4) (rows x columns)
#    Columns: ['SKU', 'Inbound_order', 'Quantity_Received', 'Date']
#
#  Sheet 'Inbound_Avg' loaded:
#    Shape: (3365, 4) (rows x columns)
#    Columns: ['SKU', 'Inbound_order', 'Quantity_Received', 'Date']
#
#  Sheet 'Inventory' loaded:
#    Shape: (38716, 3) (rows x columns)
#    Columns: ['Date', 'SKU', 'Quantity_inventory']
#
#  Sheet 'Inventory' loaded:
#    Shape: (38716, 3) (rows x columns)
#    Columns: ['Date', 'SKU', 'Quantity_inventory']
#
#  Sheet 'Picking_95%' loaded:
#    Shape: (52162, 4) (rows x columns)
#    Columns: ['SHIP_DATE', 'Store_ID', 'PIECES_PICKED', 'SKU']
#
#  Sheet 'Picking_95%' loaded:
#    Shape: (52162, 4) (rows x columns)
#    Columns: ['SHIP_DATE', 'Store_ID', 'PIECES_PICKED', 'SKU']
#
#  Sheet 'Picking_Avg' loaded:
#    Shape: (35696, 4) (rows x columns)
#    Columns: ['SHIP_DATE', 'Store_ID', 'PIECES_PICKED', 'SKU']
#
# Successfully loaded 6 DataFrames!
# Access them using: dataframes['sheet_name']
#
#  Sheet 'Picking_Avg' loaded:
#    Shape: (35696, 4) (rows x columns)
#    Columns: ['SHIP_DATE', 'Store_ID', 'PIECES_PICKED', 'SKU']
#
# Successfully loaded 6 DataFrames!
# Access them using: dataframes['sheet_name']

# %%
# Explore the DataFrames
print("=== DataFrame Exploration ===")

for sheet_name, df in dataframes.items():
    print(f"\nSheet: {sheet_name}")
    print(f"Shape: {df.shape}")
    print(f"Data types:")
    print(df.dtypes)
    print(f"\nFirst 3 rows:")
    display(df.head(3))
    print("-" * 50)
# Out:
# === DataFrame Exploration ===
#
# Sheet: Masterdata
# Shape: (86174, 5)
# Data types:
# SKU              int64
# Weight [kg]     object
# Length [cm]    float64
# Width [cm]     float64
# Height [cm]     object
# dtype: object
#
# First 3 rows:
#               SKU Weight [kg]  Length [cm]  Width [cm] Height [cm]
# 0  22313297332509        2.03        42.18       17.95        9.71
# 1  37052307296556        1.94        39.19       18.93        8.71
# 2  36945144190138        0.43        22.65       16.98        9.93
# --------------------------------------------------
#
# Sheet: Inbound_95%
# Shape: (4083, 4)
# Data types:
# SKU                           int64
# Inbound_order                 int64
# Quantity_Received            object
# Date                 datetime64[ns]
# dtype: object
#
# First 3 rows:
#               SKU  Inbound_order Quantity_Received       Date
# 0  33182402079932    23165509382                 1 2023-06-28
# 1  23693041278671    23537976965                 1 2023-06-26
# 2  23510956951343    23579822364                 1 2023-06-29
# --------------------------------------------------
#
# Sheet: Inbound_Avg
# Shape: (3365, 4)
# Data types:
# SKU                           int64
# Inbound_order                 int64
# Quantity_Received            object
# Date                 datetime64[ns]
# dtype: object
#
# First 3 rows:
#               SKU  Inbound_order Quantity_Received       Date
# 0  36027721626904    23729684391                 1 2023-02-06
# 1  20636028400143    23813878930                 1 2023-02-06
# 2  22896485876288    23676413786                 1 2023-02-07
# --------------------------------------------------
#
# Sheet: Inventory
# Shape: (38716, 3)
# Data types:
# Date                  datetime64[ns]
# SKU                            int64
# Quantity_inventory            object
# dtype: object
#
# First 3 rows:
#         Date             SKU Quantity_inventory
# 0 2023-03-31  23741591929768                  1
# 1 2023-03-31  27955396164403                  1
# 2 2023-03-31  38199064789544                  1
# --------------------------------------------------
#
# Sheet: Picking_95%
# Shape: (52162, 4)
# Data types:
# SHIP_DATE        datetime64[ns]
# Store_ID                  int64
# PIECES_PICKED             int64
# SKU                       int64
# dtype: object
#
# First 3 rows:
#    SHIP_DATE     Store_ID  PIECES_PICKED             SKU
# 0 2023-09-05  69000109445              1  34132173287369
# 1 2023-09-05  69000590822              1  39664936031107
# 2 2023-09-05  69000490669              1  30012030061218
# --------------------------------------------------
#
# Sheet: Picking_Avg
# Shape: (35696, 4)
# Data types:
# SHIP_DATE        datetime64[ns]
# Store_ID                  int64
# PIECES_PICKED             int64
# SKU                       int64
# dtype: object
#
# First 3 rows:
#    SHIP_DATE     Store_ID  PIECES_PICKED             SKU
# 0 2023-05-31  69000987218             20  30778687594764
# 1 2023-05-31  69000866767              3  23200750992246
# 2 2023-05-31  69000370983              1  30581603017818
# --------------------------------------------------

# %%
# Define column types for each sheet
COLUMN_TYPES = {
    'Masterdata': {
        'SKU': 'string',
        'Weight [kg]': 'float64',
        'Height [cm]': 'float64',
        'Length [cm]': 'float64',
        'Width [cm]': 'float64'
    },
    'Inbound_95%': {
        'SKU': 'string',
        'Inbound_order': 'string',
        'Quantity_Received': 'float64',
        'Date': 'datetime64[ns]'
     },
     'Inbound_Avg': {
        'SKU': 'string',
        'Inbound_order': 'string',
        'Quantity_Received': 'float64',
        'Date': 'datetime64[ns]'
     },
     'Inventory': {
        'Date': 'datetime64[ns]',
        'SKU': 'string',
        'Quantity_inventory': 'float64'
     },
     'Picking_95%': {
        'SHIP_DATE': 'datetime64[ns]',
        'Store_ID': 'string',
        'PIECES_PICKED': 'float64',
        'SKU': 'string'
     },
     'Picking_Avg': {
        'SHIP_DATE': 'datetime64[ns]',
        'Store_ID': 'string',
        'PIECES_PICKED': 'float64',
        'SKU': 'string'
     }
}

# %%
# Clean and process DataFrames
print("=== Data Cleaning ===")

cleaned_dataframes = {}

for sheet_name, df in dataframes.items():
    print(f"\nCleaning sheet: {sheet_name}")
    
    # Make a copy to avoid modifying original
    cleaned_df = df.copy()
    
    # Find and process SKU columns
    sku_columns = [col for col in cleaned_df.columns if 'sku' in col.lower()]
    
    # Apply custom column types if defined
    if sheet_name in COLUMN_TYPES:
        for col_name, col_type in COLUMN_TYPES[sheet_name].items():
            if col_name in cleaned_df.columns:
                # Clean space-separated numbers before conversion
                if 'float' in col_type or 'int' in col_type:
                    # Remove spaces from numeric values (handles "1 032" -> "1032")
                    cleaned_df[col_name] = cleaned_df[col_name].astype(str).str.replace(r'\s+', '', regex=True)
                    # Convert back to numeric
                    cleaned_df[col_name] = pd.to_numeric(cleaned_df[col_name], errors='coerce').astype(col_type)
                else:
                    # For non-numeric types (string, datetime), use regular conversion
                    cleaned_df[col_name] = pd.to_numeric(cleaned_df[col_name], errors='coerce').astype(col_type)
                print(f"     {col_name} → {col_type}")
    
    cleaned_dataframes[sheet_name] = cleaned_df

print(f"Access cleaned data using: cleaned_dataframes['sheet_name']")
# Out:
# === Data Cleaning ===
#
# Cleaning sheet: Masterdata
#      SKU → string
#      SKU → string
#      Weight [kg] → float64
#      Height [cm] → float64
#      Weight [kg] → float64
#      Height [cm] → float64
#      Length [cm] → float64
#      Length [cm] → float64
#      Width [cm] → float64
#
# Cleaning sheet: Inbound_95%
#      SKU → string
#      Inbound_order → string
#      Quantity_Received → float64
#      Date → datetime64[ns]
#
# Cleaning sheet: Inbound_Avg
#      SKU → string
#      Inbound_order → string
#      Quantity_Received → float64
#      Date → datetime64[ns]
#
# Cleaning sheet: Inventory
#      Date → datetime64[ns]
#      SKU → string
#      Quantity_inventory → float64
#
# Cleaning sheet: Picking_95%
#      SHIP_DATE → datetime64[ns]
#      Store_ID → string
#      Width [cm] → float64
#
# Cleaning sheet: Inbound_95%
#      SKU → string
#      Inbound_order → string
#      Quantity_Received → float64
#      Date → datetime64[ns]
#
# Cleaning sheet: Inbound_Avg
#      SKU → string
#      Inbound_order → string
#      Quantity_Received → float64
#      Date → datetime64[ns]
#
# Cleaning sheet: Inventory
#      Date → datetime64[ns]
#      SKU → string
#      Quantity_inventory → float64
#
# Cleaning sheet: Picking_95%
#      SHIP_DATE → datetime64[ns]
#      Store_ID → string
#      PIECES_PICKED → float64
#      SKU → string
#
# Cleaning sheet: Picking_Avg
#      SHIP_DATE → datetime64[ns]
#      Store_ID → string
#      PIECES_PICKED → float64
#      SKU → string
# Access cleaned data using: cleaned_dataframes['sheet_name']
#      PIECES_PICKED → float64
#      SKU → string
#
# Cleaning sheet: Picking_Avg
#      SHIP_DATE → datetime64[ns]
#      Store_ID → string
#      PIECES_PICKED → float64
#      SKU → string
# Access cleaned data using: cleaned_dataframes['sheet_name']

# %%
# Data Integrity Check
print("=== Data Integrity Verification ===")

for sheet_name in dataframes.keys():
    print(f"\n📊 Sheet: {sheet_name}")
    
    original_df = dataframes[sheet_name]
    cleaned_df = cleaned_dataframes[sheet_name] if sheet_name in cleaned_dataframes else None
    
    if cleaned_df is not None:
        # Check row counts match
        print(f"   Rows: Original={len(original_df)}, Cleaned={len(cleaned_df)} {'✅' if len(original_df) == len(cleaned_df) else '❌'}")
        
        # Check for NaN/null values in cleaned data
        null_counts = cleaned_df.isnull().sum()
        total_nulls = null_counts.sum()
        
        if total_nulls == 0:
            print(f"   Null/NaN values: ✅ None found")
        else:
            print(f"   Null/NaN values: ❌ Found {total_nulls} total")
            for col, count in null_counts.items():
                if count > 0:
                    percentage = (count / len(cleaned_df)) * 100
                    print(f"     {col}: {count} nulls ({percentage:.1f}%)")
        
        # Show data types after cleaning
        print(f"   Data types after cleaning:")
        for col, dtype in cleaned_df.dtypes.items():
            print(f"     {col}: {dtype}")
            
        # Sample comparison for first few values
        print(f"   Sample data comparison:")
        for col in cleaned_df.columns[:3]:  # Show first 3 columns
            if col in original_df.columns:
                orig_sample = original_df[col].head(2).tolist()
                clean_sample = cleaned_df[col].head(2).tolist()
                print(f"     {col}: {orig_sample} → {clean_sample}")
    else:
        print(f"   ❌ No cleaned version found")
    
    print("-" * 60)
# Out:
# === Data Integrity Verification ===
#
# 📊 Sheet: Masterdata
#    Rows: Original=86174, Cleaned=86174 ✅
#    Null/NaN values: ❌ Found 7 total
#      Weight [kg]: 6 nulls (0.0%)
#      Height [cm]: 1 nulls (0.0%)
#    Data types after cleaning:
#      SKU: string
#      Weight [kg]: float64
#      Length [cm]: float64
#      Width [cm]: float64
#      Height [cm]: float64
#    Sample data comparison:
#      SKU: [22313297332509, 37052307296556] → ['22313297332509', '37052307296556']
#      Weight [kg]: [2.03, 1.94] → [2.03, 1.94]
#      Length [cm]: [42.18, 39.19] → [42.18, 39.19]
# ------------------------------------------------------------
#
# 📊 Sheet: Inbound_95%
#    Rows: Original=4083, Cleaned=4083 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SKU: string
#      Inbound_order: string
#      Quantity_Received: float64
#      Date: datetime64[ns]
#    Sample data comparison:
#      SKU: [33182402079932, 23693041278671] → ['33182402079932', '23693041278671']
#      Inbound_order: [23165509382, 23537976965] → ['23165509382', '23537976965']
#      Quantity_Received: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Inbound_Avg
#    Rows: Original=3365, Cleaned=3365 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SKU: string
#      Inbound_order: string
#      Quantity_Received: float64
#      Date: datetime64[ns]
#    Sample data comparison:
#      SKU: [36027721626904, 20636028400143] → ['36027721626904', '20636028400143']
#      Inbound_order: [23729684391, 23813878930] → ['23729684391', '23813878930']
#      Quantity_Received: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Inventory
#    Rows: Original=38716, Cleaned=38716 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      Date: datetime64[ns]
#      SKU: string
#      Quantity_inventory: float64
#    Sample data comparison:
#      Date: [Timestamp('2023-03-31 00:00:00'), Timestamp('2023-03-31 00:00:00')] → [Timestamp('2023-03-31 00:00:00'), Timestamp('2023-03-31 00:00:00')]
#      SKU: [23741591929768, 27955396164403] → ['23741591929768', '27955396164403']
#      Quantity_inventory: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Picking_95%
#    Rows: Original=52162, Cleaned=52162 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SHIP_DATE: datetime64[ns]
#      Store_ID: string
#      PIECES_PICKED: float64
#      SKU: string
#    Sample data comparison:
#      SHIP_DATE: [Timestamp('2023-09-05 00:00:00'), Timestamp('2023-09-05 00:00:00')] → [Timestamp('2023-09-05 00:00:00'), Timestamp('2023-09-05 00:00:00')]
#      Store_ID: [69000109445, 69000590822] → ['69000109445', '69000590822']
#      PIECES_PICKED: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Picking_Avg
#    Rows: Original=35696, Cleaned=35696 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SHIP_DATE: datetime64[ns]
#      Store_ID: string
#      PIECES_PICKED: float64
#      SKU: string
#    Sample data comparison:
#      SHIP_DATE: [Timestamp('2023-05-31 00:00:00'), Timestamp('2023-05-31 00:00:00')] → [Timestamp('2023-05-31 00:00:00'), Timestamp('2023-05-31 00:00:00')]
#      Store_ID: [69000987218, 69000866767] → ['69000987218', '69000866767']
#      PIECES_PICKED: [20, 3] → [20.0, 3.0]
# ------------------------------------------------------------
#    Null/NaN values: ❌ Found 7 total
#      Weight [kg]: 6 nulls (0.0%)
#      Height [cm]: 1 nulls (0.0%)
#    Data types after cleaning:
#      SKU: string
#      Weight [kg]: float64
#      Length [cm]: float64
#      Width [cm]: float64
#      Height [cm]: float64
#    Sample data comparison:
#      SKU: [22313297332509, 37052307296556] → ['22313297332509', '37052307296556']
#      Weight [kg]: [2.03, 1.94] → [2.03, 1.94]
#      Length [cm]: [42.18, 39.19] → [42.18, 39.19]
# ------------------------------------------------------------
#
# 📊 Sheet: Inbound_95%
#    Rows: Original=4083, Cleaned=4083 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SKU: string
#      Inbound_order: string
#      Quantity_Received: float64
#      Date: datetime64[ns]
#    Sample data comparison:
#      SKU: [33182402079932, 23693041278671] → ['33182402079932', '23693041278671']
#      Inbound_order: [23165509382, 23537976965] → ['23165509382', '23537976965']
#      Quantity_Received: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Inbound_Avg
#    Rows: Original=3365, Cleaned=3365 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SKU: string
#      Inbound_order: string
#      Quantity_Received: float64
#      Date: datetime64[ns]
#    Sample data comparison:
#      SKU: [36027721626904, 20636028400143] → ['36027721626904', '20636028400143']
#      Inbound_order: [23729684391, 23813878930] → ['23729684391', '23813878930']
#      Quantity_Received: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Inventory
#    Rows: Original=38716, Cleaned=38716 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      Date: datetime64[ns]
#      SKU: string
#      Quantity_inventory: float64
#    Sample data comparison:
#      Date: [Timestamp('2023-03-31 00:00:00'), Timestamp('2023-03-31 00:00:00')] → [Timestamp('2023-03-31 00:00:00'), Timestamp('2023-03-31 00:00:00')]
#      SKU: [23741591929768, 27955396164403] → ['23741591929768', '27955396164403']
#      Quantity_inventory: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Picking_95%
#    Rows: Original=52162, Cleaned=52162 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SHIP_DATE: datetime64[ns]
#      Store_ID: string
#      PIECES_PICKED: float64
#      SKU: string
#    Sample data comparison:
#      SHIP_DATE: [Timestamp('2023-09-05 00:00:00'), Timestamp('2023-09-05 00:00:00')] → [Timestamp('2023-09-05 00:00:00'), Timestamp('2023-09-05 00:00:00')]
#      Store_ID: [69000109445, 69000590822] → ['69000109445', '69000590822']
#      PIECES_PICKED: [1, 1] → [1.0, 1.0]
# ------------------------------------------------------------
#
# 📊 Sheet: Picking_Avg
#    Rows: Original=35696, Cleaned=35696 ✅
#    Null/NaN values: ✅ None found
#    Data types after cleaning:
#      SHIP_DATE: datetime64[ns]
#      Store_ID: string
#      PIECES_PICKED: float64
#      SKU: string
#    Sample data comparison:
#      SHIP_DATE: [Timestamp('2023-05-31 00:00:00'), Timestamp('2023-05-31 00:00:00')] → [Timestamp('2023-05-31 00:00:00'), Timestamp('2023-05-31 00:00:00')]
#      Store_ID: [69000987218, 69000866767] → ['69000987218', '69000866767']
#      PIECES_PICKED: [20, 3] → [20.0, 3.0]
# ------------------------------------------------------------

# %%
# Deep Dive: Inbound_95% Problems
print("=== Investigating Masterdata Issues ===")

if 'Masterdata' in dataframes:
    original = dataframes['Masterdata']
    cleaned = cleaned_dataframes['Masterdata']

    print(f"Original data shape: {original.shape}")
    print(f"Cleaned data shape: {cleaned.shape}")
    
    # Check each column that was supposed to be converted
    if 'Masterdata' in COLUMN_TYPES:
        for col_name, target_type in COLUMN_TYPES['Masterdata'].items():
            if col_name in original.columns:
                print(f"\n🔍 Column: {col_name} (target: {target_type})")
                
                # Show original data types and samples
                print(f"   Original dtype: {original[col_name].dtype}")
                print(f"   Original unique values (first 10): {original[col_name].unique()[:10]}")
                
                # Test the conversion step by step
                try:
                    converted = pd.to_numeric(original[col_name], errors='coerce')
                    nan_count = converted.isnull().sum()
                    print(f"   After pd.to_numeric: {nan_count} NaN values created")
                    
                    if nan_count > 0:
                        # Find problematic values
                        problematic = original[col_name][converted.isnull() & original[col_name].notna()]
                        print(f"   Problematic values: {problematic.unique()[:10]}")
                        print(f"   Sample problematic rows:")
                        for idx in problematic.index[:3]:
                            print(f"     Row {idx}: '{original.loc[idx, col_name]}' (type: {type(original.loc[idx, col_name])})")
                            
                except Exception as e:
                    print(f"   Error during conversion: {e}")
                
                print("-" * 40)
else:
    print("Masterdata% sheet not found")
# Out:
# === Investigating Masterdata Issues ===
# Original data shape: (86174, 5)
# Cleaned data shape: (86174, 5)
#
# 🔍 Column: SKU (target: string)
#    Original dtype: int64
#    Original unique values (first 10): [22313297332509 37052307296556 36945144190138 30323209107949
#  29589758427373 38570265235265 32574029120559 37649556977605
#  23710805288818 28542325106326]
#    After pd.to_numeric: 0 NaN values created
# ----------------------------------------
#
# 🔍 Column: Weight [kg] (target: float64)
#    Original dtype: object
#    Original unique values (first 10): [2.03 1.94 0.43 0.13 1.55 1.57 0.12 0.45 1.58 0.2]
#    After pd.to_numeric: 6 NaN values created
#    Problematic values: ['-0,21' '-0,0' '-0,54' '-0,53']
#    Sample problematic rows:
#      Row 2093: '-0,21' (type: <class 'str'>)
#      Row 16847: '-0,0' (type: <class 'str'>)
#      Row 26230: '-0,54' (type: <class 'str'>)
# ----------------------------------------
#
# 🔍 Column: Height [cm] (target: float64)
#    Original dtype: object
#    Original unique values (first 10): [9.71 8.71 9.93 1.38 8.88 9.29 1.32 10.31 11.91 2.34]
#    After pd.to_numeric: 1 NaN values created
#    Problematic values: ['-0,79']
#    Sample problematic rows:
#      Row 66363: '-0,79' (type: <class 'str'>)
# ----------------------------------------
#
# 🔍 Column: Length [cm] (target: float64)
#    Original dtype: float64
#    Original unique values (first 10): [42.18 39.19 22.65 33.45 39.04 36.57 31.31 24.25 43.37 27.14]
#    After pd.to_numeric: 0 NaN values created
# ----------------------------------------
#
# 🔍 Column: Width [cm] (target: float64)
#    Original dtype: float64
#    Original unique values (first 10): [17.95 18.93 16.98 25.23 18.05 18.72 24.89 17.33 17.62 19.36]
#    After pd.to_numeric: 0 NaN values created
# ----------------------------------------
#    After pd.to_numeric: 1 NaN values created
#    Problematic values: ['-0,79']
#    Sample problematic rows:
#      Row 66363: '-0,79' (type: <class 'str'>)
# ----------------------------------------
#
# 🔍 Column: Length [cm] (target: float64)
#    Original dtype: float64
#    Original unique values (first 10): [42.18 39.19 22.65 33.45 39.04 36.57 31.31 24.25 43.37 27.14]
#    After pd.to_numeric: 0 NaN values created
# ----------------------------------------
#
# 🔍 Column: Width [cm] (target: float64)
#    Original dtype: float64
#    Original unique values (first 10): [17.95 18.93 16.98 25.23 18.05 18.72 24.89 17.33 17.62 19.36]
#    After pd.to_numeric: 0 NaN values created
# ----------------------------------------
